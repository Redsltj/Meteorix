# %% [markdown]
# # Partie3: Image artificielle
#
#
# Pour créer une image du météore en mouvement, il faudra suivre sa position à chaque instant en utilisant les données de temps et de position obtenues précédemment. On peut commencer par définir une position initiale pour le météore dans l'image (par exemple, en choisissant le centre de l'image comme position initiale). Ensuite, pour chaque instant de temps, on pourra calculer la nouvelle position du météore en fonction de sa vitesse et de sa direction.
#
# Pour chaque position du météore, on pourra ensuite calculer la luminosité des pixels de l'image sur lesquels la lumière du météore tombe en utilisant les valeurs de signal détecté obtenues précédemment. Les pixels saturés pourront être réglés au niveau de gris maximum de la caméra (par exemple, 255 pour une caméra 8 bits) pour éviter la surexposition de l'image.
#
# Il est important de noter que le reste de l'image doit être noir (niveau de gris = 0) pour pouvoir distinguer le météore des autres objets de l'image. En effet, si l'image est trop lumineuse, il sera difficile de voir le météore distinctement. Il est donc important de bien calibrer l'exposition de la caméra et de ne pas surexposer l'image.

# %%
import numpy as np
import cv2

# Définir les paramètres du météore et de la caméra
Xm = [0, 0]  # Position initiale du météore (à ajuster selon l'image)
#Je définis la vitesse du météore comme étant de 10 pixels par seconde dans 
#la direction horizontale (axe x) et de 5 pixels par seconde dans 
#la direction verticale (axe y). Cela signifie que pour chaque seconde qui passe,
# le météore se déplace de 10 pixels vers la droite et de 5 pixels vers le bas
#ces valeurs necessite d'être modifiées en fonction de la vitesse réelle du météore que nous voulons  simuler.
vitesse = [10, 5]  # Vitesse du météore en pixels/s
temps = np.arange(0, 500, 15)  # Intervalle de temps en secondes(à modifié avec les valeurs de temps d'exposition) 
signal_detecte = [...]  # Signal détecté en fonction du temps (à remplir)
taille_image = [800, 800]  # Taille de l'image en pixels(dépend de la camera utilisée,c'est à modifier d'après notre camera)
max_intensite = 255  # Valeur maximale de la luminosité des pixels(pareil aussi, c'est l'intensité maximale que la camera peut capter, c'est à modifier)

# %% [markdown]
# # Initialiser l'image
# On crée une liste vide pour stocker les images.

# %%
image = np.zeros((taille_image[0], taille_image[1]), dtype=np.uint8)

# %% [markdown]
# # Boucle sur chaque instant de temps
# On itère sur les temps de l'observation en utilisant une boucle for.

# %%
for t, signal in zip(temps, signal_detecte);
# Out:
#   File "<ipython-input-5-fed937c13bd1>", line 1
#     for t, signal in zip(temps, signal_detecte)
#                                                ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Calcule de la nouvelle position du météore
#
# On calcule la position horizontale (x_pos) du météore sur l'image en fonction de sa position initiale (xm), de sa vitesse horizontale (vit_x), du temps actuel (t[i]) et du pas de temps (pas_temps). La fonction int() permet de convertir le résultat en entier car la position des pixels doit être exprimée en nombre entier. On calcule la position verticale (y_pos) du météore sur l'image de la même manière que la position horizontale.

# %%
for t, signal in zip(temps, signal_detecte):
   x_pos = int(xm + vit_x * t[i] / pas_temps) # On calcule la position en x du météore sur l'image
   y_pos = int(ym + vit_y * t[i] / pas_temps) # On calcule la position en y du météore sur l'image
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-f8455b6c09d8> in <module>
#       1 for t, signal in zip(temps, signal_detecte):
# ----> 2    x_pos = int(xm + vit_x * t[i] / pas_temps) # On calcule la position en x du météore sur l'image
#       3    y_pos = int(ym + vit_y * t[i] / pas_temps) # On calcule la position en y du météore sur l'image
#
# NameError: name 'xm' is not defined

# %% [markdown]
# # création d'une image noire
#
# On crée une image noire en utilisant la fonction np.zeros() de NumPy, qui crée un tableau de dimensions spécifiées rempli de zéros. On spécifie la hauteur et la largeur de l'image en utilisant les variables hauteur_image et largeur_image. On utilise le type np.uint8 pour spécifier que les valeurs de l'image sont des entiers non signés codés sur 8 bits (valeurs de 0 à 255).

# %%
img = np.zeros((hauteur_image, largeur_image), dtype=np.uint8

# %% [markdown]
# # Calcule de la luminosité des pixels touchés par le météore
